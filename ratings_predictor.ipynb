# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud

# Importing nltk libraries
import re
import string
#import missingno
#import pandas_profiling
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import FreqDist

from scipy import stats
from scipy.stats import zscore
from scipy.sparse import hstack
#import scikitplot as skplt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV 
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score, precision_score, confusion_matrix, accuracy_score, classification_report

from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression
#from lightgbm import LGBMClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost.sklearn import XGBClassifier

import warnings
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")
import joblib

lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
import pandas as pd
from nltk.corpus import stopwords
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re
import time
from nltk.tokenize import word_tokenize, regexp_tokenize
import wikipedia
import sys
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,roc_curve, roc_auc_score, plot_roc_curve
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor,RandomForestClassifier, BaggingClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import xgboost as xgb
import pickle
import time
import PIL

#import plotty
import warnings
warnings.filterwarnings('ignore')

# Importing required libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
 
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.metrics import hamming_loss, log_loss

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder, LabelEncoder, PowerTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,roc_curve, roc_auc_score, plot_roc_curve
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor,RandomForestClassifier, BaggingClassifier
from sklearn.metrics import confusion_matrix, classification_report
from scipy.stats import norm, stats
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import statistics as st
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
import time


#import plotty
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C://Users//hp-pc//Desktop//Internship22//Ratings_prediction_project//Scrape_code.csv")
df#read csv file
# Out:
#        Unnamed: 0  Number of Stars         Short Review  \
# 0               0                4          Really Nice
# 1               1                5              Awesome
# 2               2                5            Fabulous!
# 3               3                5  Best in the market!
# 4               4                5     Perfect product!
# ...           ...              ...                  ...
# 24464        6235                5       Classy product
# 24465        6236                5            Excellent
# 24466        6237                5            Fabulous!
# 24467        6238                2          Bad quality
# 24468        6239                2          Bad quality
#
#                                              Full Review
# 0      Nice packaging by flipkart n timely delivery 2...
# 1      Overall functions are good camera Quility is q...
# 2      Except for Low Ringtone the phone fulfills the...
# 3      Phone is just awesome everything is so good . ...
# 4      Nicely delivered\nValue for money I brought it...
# ...                                                  ...
# 24464  I wrote this statement after 4 month . It is v...
# 24465  It is very nice and battery backup is very nic...
# 24466                                               Oook
# 24467                    Very bad sound and bettery life
# 24468                  Verry bad this is not a Bluetooth
#
# [24469 rows x 4 columns]

# %%
#drop unnecessary column
df.drop(columns='Unnamed: 0', inplace = True)

# %%
df.head(10)
# Out:
#    Number of Stars           Short Review  \
# 0                4            Really Nice
# 1                5                Awesome
# 2                5              Fabulous!
# 3                5    Best in the market!
# 4                5       Perfect product!
# 5                3              Just okay
# 6                4            Good choice
# 7                5              Wonderful
# 8                5  Mind-blowing purchase
# 9                5         Simply awesome
#
#                                          Full Review
# 0  Nice packaging by flipkart n timely delivery 2...
# 1  Overall functions are good camera Quility is q...
# 2  Except for Low Ringtone the phone fulfills the...
# 3  Phone is just awesome everything is so good . ...
# 4  Nicely delivered\nValue for money I brought it...
# 5  Realme C11 2021 edition is nice\nI am Purchase...
# 6  Best phone in this budget\nBut if u have more ...
# 7  According to its price range, it is a very goo...
# 8  Such a good product very happy with it best ca...
# 9  Good phone at this price,Ram is enough for nor...

# %%
df.shape
# Out:
# (24469, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24469 entries, 0 to 24468
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Number of Stars  24469 non-null  int64
#  1   Short Review     24469 non-null  object
#  2   Full Review      24469 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 573.6+ KB

# %%
df.describe()
# Out:
#        Number of Stars
# count     24469.000000
# mean          4.280763
# std           1.233542
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000

# %%
df.isnull().sum()
# Out:
# Number of Stars    0
# Short Review       0
# Full Review        0
# dtype: int64

# %%
df = df.rename(columns = {"Full Review":"Full_Review"})

# %%
df["Number of Stars"].unique()
# Out:
# array([4, 5, 3, 2, 1], dtype=int64)

# %%
df["Number of Stars"].value_counts()
# Out:
# 5    15858
# 4     4584
# 1     2196
# 3     1262
# 2      569
# Name: Number of Stars, dtype: int64

# %%
#plotting each class frequency
fig = plt.figure(figsize=(8,5))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Number of Stars",palette="Set2", data=df, order = df["Number of Stars"].value_counts().index)
plt.show()

# %%
#Checking the length of comments and storing it into another column 'original_length'
#Copying df1 into another object df
df['original_length'] = df.Full_Review.str.len()

# %%
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

from nltk.corpus import stopwords  # Remove useless words
from nltk.stem.lancaster import LancasterStemmer  # Convert words to base form; aggressive
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\hp-
# [nltk_data]     pc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#Lancaster stemmer
lnc=LancasterStemmer()

# %%
#defining a function to remove stopwords from the text
def clean(text):
    try:
        cleaned=''
        stop_words=stopwords.words('english')
        lower_text=text.lower() #converting the text data to lowercase because the stopwords are in lowercase
        for sent_token in sent_tokenize(lower_text): #Splitting the text into tokens of sentences
            for word in nltk.word_tokenize(sent_token):#splitting the tokens of sentences into tokens of words
                if word not in stop_words:
                    stemmed=lnc.stem(word)
                    cleaned=cleaned+' '+stemmed
            #cleaned=cleaned+' '   So that the words dont merge when the '.' is removed as a punctuation
    except Exception as e:
        print("exception in",text,e )
    return cleaned

# %%
df
# Out:
#        Number of Stars         Short Review  \
# 0                    4          Really Nice
# 1                    5              Awesome
# 2                    5            Fabulous!
# 3                    5  Best in the market!
# 4                    5     Perfect product!
# ...                ...                  ...
# 24464                5       Classy product
# 24465                5            Excellent
# 24466                5            Fabulous!
# 24467                2          Bad quality
# 24468                2          Bad quality
#
#                                              Full_Review  original_length
# 0      Nice packaging by flipkart n timely delivery 2...              188
# 1      Overall functions are good camera Quility is q...              144
# 2      Except for Low Ringtone the phone fulfills the...              360
# 3      Phone is just awesome everything is so good . ...              173
# 4      Nicely delivered\nValue for money I brought it...              172
# ...                                                  ...              ...
# 24464  I wrote this statement after 4 month . It is v...               80
# 24465  It is very nice and battery backup is very nic...               96
# 24466                                               Oook                4
# 24467                    Very bad sound and bettery life               31
# 24468                  Verry bad this is not a Bluetooth               33
#
# [24469 rows x 4 columns]

# %%
#Removing stopwords from the text data

for i in range(len(df)):
    df['Full_Review'][i]=clean(df['Full_Review'][i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Full Review'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-0a606b2d6714> in <module>
#       2
#       3 for i in range(len(df)):
# ----> 4     df['Full Review'][i]=clean(df['Full Review'][i])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Full Review'

# %%
df = df.rename(columns = {"Short Review":"Short_Review"})

# %%
df = df.rename(columns = {"Number of Stars":"Ratings"})

# %%
#Removing and Replacing unwanted characters in the comment_text column

#Replacing '\n' with ' '
df.Full_Review = df.Full_Review.str.replace('\n',' ').str.lower()

#Keeping only text with letters a to z, 0 to 9 and words like can't, don't, couldn't etc
df.Full_Review = df.Full_Review.apply(lambda x: ' '.join(regexp_tokenize(x,"[a-z']+")))

#Removing Stop Words and Punctuations

#Getting the list of stop words of english language as set
stop_words = set(stopwords.words('english'))

#Updating the stop_words set by adding letters from a to z
for ch in range(ord('a'),ord('z')+1):
    stop_words.update(chr(ch))
    
#Updating stop_words further by adding some custom words
custom_words = ("d'aww","mr","hmm","umm","also","maybe","that's","he's","she's","i'll","he'll","she'll","us",
                "ok","there's","hey","heh","hi","oh","bbq","i'm","i've","nt","can't","could","ur","re","ve",
                "rofl","lol","stfu","lmk","ily","yolo","smh","lmfao","nvm","ikr","ofc","omg","ilu")
stop_words.update(custom_words)

#Checking the new list of stop words
print("New list of custom stop words are as follows:\n\n")
print(stop_words)
# Out:
# New list of custom stop words are as follows:
#
#
# {'then', 'yolo', 'y', 'more', 'heh', "d'aww", 'with', 'myself', 'd', 'll', 'r', "he's", "you're", 'wouldn', 'those', 'e', "it's", 'lol', 'lmk', 'she', 'and', 'rofl', 'that', 'these', 'out', 'any', "wasn't", 'p', "she'll", 'has', 'whom', 'again', 'hey', 'g', 'too', "hadn't", 'only', 'how', 'each', 'very', 't', 'mightn', 'me', 'about', 'before', "won't", 'o', "i'm", 'needn', 'bbq', 'him', 'not', 's', 'they', 'j', 'isn', 'just', 'he', 'x', 'its', 'we', 'themselves', 'on', 'most', 'won', 'over', 'be', 'during', 'stfu', 'their', 'ofc', 're', 'wasn', 'you', 'had', 'your', 'through', 'u', 'oh', 'shouldn', 'under', 'why', 'it', 'for', 'to', 'after', 'now', 'q', "mustn't", 'mr', 'or', "i'll", 'them', 'ourselves', 'hers', "hasn't", 'don', 've', 'k', 'ilu', 'hi', 'being', "shan't", 'few', 'until', 'did', 'same', "wouldn't", 'up', 'by', 'our', 'should', 'was', 'haven', 'ok', 'ma', 'yours', 'also', 'so', 'as', 'own', 'm', "he'll", 'between', 'what', 'yourselves', 'having', 'while', 'didn', "i've", 'does', 'when', "mightn't", 'above', 'doing', 'at', 'nvm', 'which', 'in', 'both', 'hasn', 'if', "shouldn't", 'theirs', 'a', 'her', 'is', 'some', 'there', "needn't", 'the', 'against', 'l', "there's", 'will', 'are', 'because', 'couldn', 'b', 'ily', "you've", 'his', 'other', 'z', 'ours', "aren't", 'n', 'himself', 'were', 'my', 'mustn', 'h', "you'll", 'do', 'into', 'than', 'ikr', "that's", 'off', 'f', 'yourself', 'shan', 'down', 'where', 'no', 'have', 'been', 'an', 'such', "couldn't", "weren't", 'could', "doesn't", 'us', 'below', 'omg', 'who', "haven't", "should've", 'aren', "can't", "that'll", 'weren', 'umm', 'itself', 'ur', "she's", 'hmm', "you'd", 'from', 'here', 'this', 'can', 'ain', 'doesn', 'but', 'all', 'c', 'maybe', "didn't", 'hadn', 'smh', 'w', 'v', 'further', 'of', 'nor', "don't", "isn't", 'herself', 'nt', 'once', 'i', 'am', 'lmfao'}

# %%
#Removing stop words
df.Full_Review = df.Full_Review.apply(lambda x: ' '.join(word for word in x.split() if word not in stop_words).strip())

#Removing punctuations
df.Full_Review = df.Full_Review.str.replace("[^\w\d\s]","")

# %%
df.sample(10)
# Out:
#        Ratings          Short_Review  \
# 13998        4             Wonderful
# 12604        5             Fabulous!
# 13676        5               Awesome
# 22654        5               Awesome
# 4565         5               Awesome
# 9198         5        Classy product
# 14794        5             Excellent
# 20381        5        Classy product
# 15849        1       Useless product
# 20811        1  Utterly Disappointed
#
#                                              Full_Review  original_length
# 13998                     good think broke play bad good               81
# 12604                             nice easy hold playing               45
# 13676                       phone good price really like               61
# 22654  pros sound quality superb bass lovers call qua...              366
# 4565   switched android iphone transition really smoo...              497
# 9198   got iphone gb green colour expected thanks fli...              275
# 14794       awesome looking like real currency son loves               53
# 20381                                               good                4
# 15849                  bad image wise items disappointed               56
# 20811  thank flipkart fooling customers delivering pd...              353

# %%
df['Cleaned_length'] = df.Full_Review.str.len()

# %%
df
# Out:
#        Ratings         Short_Review  \
# 0            4          Really Nice
# 1            5              Awesome
# 2            5            Fabulous!
# 3            5  Best in the market!
# 4            5     Perfect product!
# ...        ...                  ...
# 24464        5       Classy product
# 24465        5            Excellent
# 24466        5            Fabulous!
# 24467        2          Bad quality
# 24468        2          Bad quality
#
#                                              Full_Review  original_length  \
# 0      nice packaging flipkart timely delivery days n...              188
# 1      overall functions good camera quility quit goo...              144
# 2      except low ringtone phone fulfills parameters ...              360
# 3      phone awesome everything good charger good tha...              173
# 4      nicely delivered value money brought small bro...              172
# ...                                                  ...              ...
# 24464       wrote statement month nice product give star               80
# 24465  nice battery backup nice sound quality superb ...               96
# 24466                                               oook                4
# 24467                             bad sound bettery life               31
# 24468                                verry bad bluetooth               33
#
#        Cleaned_length
# 0                 138
# 1                  99
# 2                 284
# 3                 109
# 4                 112
# ...               ...
# 24464              44
# 24465              61
# 24466               4
# 24467              22
# 24468              19
#
# [24469 rows x 5 columns]

# %%
#Comparing the comment text length distribution before cleaning and after cleaning.

fig, ax = plt.subplots(1,2,figsize=(15,6))
j=0
colors = ['Green','Orange']
for i in df.columns[-2:]:
    label_text = f"Distribution of Comment Length: {i}"
    sns.distplot(df[i],ax=ax[j],bins=20,color=colors[j],label=label_text)
    ax[j].set_xlabel("Length")
    ax[j].legend()
    j += 1
plt.show()

# %%
for i in df.columns[1:7]:
    df4 = df[(df[i]==1)]
    wordcloud = WordCloud(background_color = 'white', max_words= 500, stopwords= STOPWORDS, height=400, width=400).generate(str(df['Full_Review']))
    plt.figure(figsize=(3,3))
    plt.imshow(wordcloud)
    plt.title(label= f"Wordds are: {i}",fontdict={'fontsize':10, 'fontweight':10, 'color':'black'})
    plt.show()

# %%
# Creating a new feature having malignant and non malignant information for the particular comment.
label_cols = [ 'Ratings', 'Short_Review', 'Full_Review']
df['label'] = 1-df[label_cols].max(axis=1)

# %%
df
# Out:
#        Ratings         Short_Review  \
# 0            4          Really Nice
# 1            5              Awesome
# 2            5            Fabulous!
# 3            5  Best in the market!
# 4            5     Perfect product!
# ...        ...                  ...
# 24464        5       Classy product
# 24465        5            Excellent
# 24466        5            Fabulous!
# 24467        2          Bad quality
# 24468        2          Bad quality
#
#                                              Full_Review  original_length  \
# 0      nice packaging flipkart timely delivery days n...              188
# 1      overall functions good camera quility quit goo...              144
# 2      except low ringtone phone fulfills parameters ...              360
# 3      phone awesome everything good charger good tha...              173
# 4      nicely delivered value money brought small bro...              172
# ...                                                  ...              ...
# 24464       wrote statement month nice product give star               80
# 24465  nice battery backup nice sound quality superb ...               96
# 24466                                               oook                4
# 24467                             bad sound bettery life               31
# 24468                                verry bad bluetooth               33
#
#        Cleaned_length  label
# 0                 138     -3
# 1                  99     -4
# 2                 284     -4
# 3                 109     -4
# 4                 112     -4
# ...               ...    ...
# 24464              44     -4
# 24465              61     -4
# 24466               4     -4
# 24467              22     -1
# 24468              19     -1
#
# [24469 rows x 6 columns]

# %%
#split x and y
x = df.Full_Review
y=df.Ratings

# %%
from scipy.sparse import hstack
# Using the n_gram tfidf vectorizer (Word vectors)
word_vectorizer = TfidfVectorizer(sublinear_tf = True,
                                  strip_accents = 'unicode',
                                  analyzer = 'word',
                                  token_pattern = r'\w{1,}',
                                  stop_words = 'english',
                                  ngram_range = (1,3),
                                  max_features = 100000)
word_vectorizer.fit(x)
train_word_features = word_vectorizer.transform(x)

# Character vectors
char_vectorizer = TfidfVectorizer(sublinear_tf = True,
                                  strip_accents = 'unicode',
                                  analyzer = 'char',
                                  stop_words = 'english',
                                  ngram_range = (2,6),
                                  max_features = 50000)
char_vectorizer.fit(x)
train_char_features = char_vectorizer.transform(x)

# I will now combine both word vectors and character vectors as input for our model
train_features = hstack([train_char_features, train_word_features])

# %%
state = 42
x_train, x_test, y_train, y_test = train_test_split(train_features, y, test_size = 0.30, random_state = state)

# Lets check the shapes of traning and test data
print("x_train", x_train.shape)
print("x_test", x_test.shape)
print("y_train", y_train.shape)
print("y_test", y_test.shape)
# Out:
# x_train (17128, 97991)
# x_test (7341, 97991)
# y_train (17128,)
# y_test (7341,)

# %%
# Defining the Classification Machine Learning Algorithms
rf = RandomForestClassifier()
lr = LogisticRegression(solver='lbfgs')
svc = LinearSVC()
bnb = BernoulliNB()
mnb = MultinomialNB()
sgd = SGDClassifier()
xgb = XGBClassifier(verbosity=0)

# Creating a function to train and test the model with evaluation metrics
def BuiltModel(model):
    print('*'*30+model.__class__.__name__+'*'*30)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_train)
    pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, pred)*100
    print(f"ACCURACY SCORE PERCENTAGE:", accuracy)
    # Confusion matrix and Classification report
    print(f"CLASSIFICATION REPORT: \n {classification_report(y_test, pred)}")
    print(f"CONFUSION MATRIX: \n {confusion_matrix(y_test, pred)}\n")
    print("-"*120)
    print("\n")

# %%
for model in [lr,svc,bnb,mnb,sgd,rf,xgb]:
    BuiltModel(model)
# Out:
# ******************************LogisticRegression******************************
# ACCURACY SCORE PERCENTAGE: 92.14003541751805
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96       656
#            2       0.98      0.91      0.94       174
#            3       0.99      0.68      0.81       367
#            4       0.97      0.72      0.82      1327
#            5       0.90      0.99      0.94      4817
#
#     accuracy                           0.92      7341
#    macro avg       0.96      0.85      0.90      7341
# weighted avg       0.93      0.92      0.92      7341
#
# CONFUSION MATRIX:
#  [[ 628    0    0    1   27]
#  [   8  158    0    0    8]
#  [   4    0  251    5  107]
#  [   3    0    0  954  370]
#  [  11    3    3   27 4773]]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ******************************LinearSVC******************************
# ACCURACY SCORE PERCENTAGE: 93.28429369295736
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.97      0.96      0.96       656
#            2       0.97      0.96      0.96       174
#            3       0.99      0.77      0.87       367
#            4       0.96      0.75      0.84      1327
#            5       0.92      0.99      0.95      4817
#
#     accuracy                           0.93      7341
#    macro avg       0.96      0.89      0.92      7341
# weighted avg       0.94      0.93      0.93      7341
#
# CONFUSION MATRIX:
#  [[ 629    3    0    0   24]
#  [   2  167    0    2    3]
#  [   4    0  282   13   68]
#  [   3    0    0 1001  323]
#  [  11    3    3   31 4769]]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ******************************BernoulliNB******************************
# ACCURACY SCORE PERCENTAGE: 80.07083503609861
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.46      0.96      0.62       656
#            2       1.00      0.37      0.54       174
#            3       0.76      0.49      0.60       367
#            4       0.92      0.49      0.64      1327
#            5       0.88      0.90      0.89      4817
#
#     accuracy                           0.80      7341
#    macro avg       0.80      0.64      0.66      7341
# weighted avg       0.84      0.80      0.80      7341
#
# CONFUSION MATRIX:
#  [[ 633    0    3    8   12]
#  [  79   64    7    8   16]
#  [  73    0  181    3  110]
#  [ 180    0   18  654  475]
#  [ 406    0   29   36 4346]]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ******************************MultinomialNB******************************
# ACCURACY SCORE PERCENTAGE: 84.62062389320256
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.91      0.83      0.87       656
#            2       1.00      0.29      0.45       174
#            3       0.97      0.31      0.47       367
#            4       0.95      0.53      0.68      1327
#            5       0.82      1.00      0.90      4817
#
#     accuracy                           0.85      7341
#    macro avg       0.93      0.59      0.67      7341
# weighted avg       0.87      0.85      0.83      7341
#
# CONFUSION MATRIX:
#  [[ 546    0    0    7  103]
#  [  29   50    1   11   83]
#  [  14    0  113   13  227]
#  [   3    0    0  698  626]
#  [   5    0    3    4 4805]]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ******************************SGDClassifier******************************
# ACCURACY SCORE PERCENTAGE: 92.80751941152432
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96       656
#            2       0.96      0.94      0.95       174
#            3       0.98      0.77      0.86       367
#            4       0.97      0.73      0.83      1327
#            5       0.91      0.99      0.95      4817
#
#     accuracy                           0.93      7341
#    macro avg       0.96      0.88      0.91      7341
# weighted avg       0.93      0.93      0.92      7341
#
# CONFUSION MATRIX:
#  [[ 629    3    0    1   23]
#  [   5  164    0    0    5]
#  [   4    0  282    3   78]
#  [   3    0    2  967  355]
#  [  11    3    3   29 4771]]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ******************************RandomForestClassifier******************************
# ACCURACY SCORE PERCENTAGE: 93.13445034736412
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.96      0.96      0.96       656
#            2       0.97      0.96      0.96       174
#            3       0.98      0.77      0.86       367
#            4       0.96      0.75      0.84      1327
#            5       0.92      0.99      0.95      4817
#
#     accuracy                           0.93      7341
#    macro avg       0.96      0.89      0.92      7341
# weighted avg       0.93      0.93      0.93      7341
#
# CONFUSION MATRIX:
#  [[ 627    3    0    0   26]
#  [   2  167    0    2    3]
#  [   4    0  283   12   68]
#  [   6    0    2  997  322]
#  [  14    3    5   32 4763]]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#
# ******************************XGBClassifier******************************
# ACCURACY SCORE PERCENTAGE: 92.52145484266448
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            1       0.97      0.95      0.96       656
#            2       0.97      0.96      0.96       174
#            3       0.98      0.75      0.85       367
#            4       0.97      0.72      0.82      1327
#            5       0.91      0.99      0.95      4817
#
#     accuracy                           0.93      7341
#    macro avg       0.96      0.88      0.91      7341
# weighted avg       0.93      0.93      0.92      7341
#
# CONFUSION MATRIX:
#  [[ 624    3    0    1   28]
#  [   2  167    0    0    5]
#  [   4    0  277    4   82]
#  [   3    0    0  955  369]
#  [  11    3    5   29 4769]]
#
# ------------------------------------------------------------------------------------------------------------------------

# %%
start_time = time.time()

params = {'min_samples_leaf': [1, 2, 4], 'n_estimators':[10,20,30],
         'max_features':['auto',"sqrt","log2"],
         'min_samples_split':[10,11]}

gridsearch = GridSearchCV(estimator=rf, param_grid= params)#apply GridSearchCV
time.sleep(2)
print(gridsearch.fit(x_train,y_train)) #train the model
time.sleep(1)
print("\n",'*'*50)
time.sleep(1)
print('GridSearchCV best parameters:----->',gridsearch.best_params_) #get best parameters
time.sleep(1)
print("\n",'*'*50)
time.sleep(1)
#put best params
rfc = gridsearch.best_estimator_
print('Trained Model using best parameters:----->',rfc.fit(x_train,y_train)) #train the model
time.sleep(1)
print("\n",'*'*50)
time.sleep(1)
y_pred = rfc.predict(x_test) # predict it
r2_score(y_test, y_pred) # get the improved r2 score
print('Accuracy score:------>',r2_score(y_test, y_pred))#check the accuracy score
print("\n",'*'*50)

end_time = time.time()
T = (end_time - start_time)/60
print("Total time taken (in mins):------>", T )
